# %% [markdown]
# # Recall

# %% [markdown]
# ![function_illustration.png](attachment:82271c29-b6fb-4d30-b104-90ecdd882313.png)

# %% [markdown]
# <font size="5">We know that: if we user the function *min* and pass two values (separated by a comma) with in the paranthesis after *min*, i.e., </font>
#
# <font size="4.5">*min(value_1, value_2)*</font>
#
# <font size="5">We magically get the minimum of the two values as the output and can be assigned to a variable.</font>

# %%
value_1 = 10
value_2 = 20
value_result = min(value_1, value_2)

print("The minimum of", value_1, "and", value_2, "is", value_result)
# Out:
# The minimum of 10 and 20 is 10

# %% [markdown]
# <font size="5">Similarly, what if I want to use a function to find the area of a circle where I just pass the radius of the circle in the paranthesis. </font>`

# %% [markdown]
# <font size="4.5">*find_area_circle(radius)*</font>

# %% [markdown]
# ![Func_area_circle.png](attachment:e6a5c31e-a0ef-4bd9-86d5-79c822791947.png)

# %% [markdown]
# ![Func_expln.png](attachment:b3a32a4d-8767-4b86-a752-0b750f64bd1f.png)

# %% [markdown]
# <font size="5">**Forms of Functions.**</font>
#
# A function can take up different forms based on the presence/absence of parameter/s and/or reutrn value/s.

# %% [markdown]
# <font size="4.5">**Form 1:** *Function with no input parameter/s and no return value/s*</font>
#
# ![image.png](attachment:f9969a29-b4f4-41e7-92ca-c6b76fbaedd0.png)

# %% [markdown]
# Example: You want to create a function just to greet the user.

# %%
"""
This is a doc string. Use this to let the user know what this function is doing.
"""

# %% [markdown]
# # A function to send a greeting message to players.

# %%
def greetings():
    print("Welcome to the RPS game!")


greetings()
# Out:
# Welcome to the RPS game!

# %% [markdown]
# <font size="4.5">**Form 2:** *Function with no input parameter/s but with return value/s*</font>
#
# ![image.png](attachment:a1714593-ed30-4b35-aa7b-412f09dbff2c.png)

# %% [markdown]
# Example: You want to have a function just to enforce a positive input integer.

# %%
"""
This is a doc string. Use this to let the user know what this function is doing.
"""

# %% [markdown]
# # A function to get user input for RPS

# %%
def get_user_inputs():
    while True:
        value = int(input("Press 0 for Rock. Press 1 for Paper. Press 2 for Scissors."))
        if (value <0 or value >2):
            continue
        else:
            return value



choices = ["Rock", "Paper", "Scissors"]
user_choice = get_user_inputs() # from line 12 the translator jumps to line 1
print("The user choice is:", choices[user_choice])
# Out:
# Press 0 for Rock. Press 1 for Paper. Press 2 for Scissors. 5
# Press 0 for Rock. Press 1 for Paper. Press 2 for Scissors. 7
# Press 0 for Rock. Press 1 for Paper. Press 2 for Scissors. 2
# The user choice is: Scissors

# %% [markdown]
# <font size="4.5">**Form 3:** *Function with input parameter/s and without return value/s*</font>
#
# Functions with input parameter/s but without return value/s are versatile and can be used in various scenarios where the primary goal is to perform an action or produce a side effect rather than compute and return a value.
#
# ![image.png](attachment:1f852e5c-468b-4180-adbd-81af4974ff29.png)

# %% [markdown]
# Example: You want to print message or to call other functions. (We will see more in CSI 260)

# %% [markdown]
# # A function that gets user's and computer's final score and displays the result and decides the over all winner.

# %%
def final_result(user_score, computer_score):
    print("The final scores are:")
    print("User:", user_score, "Computer:", computer_score)
    if(user_score > computer_score):
        print("User is the winner")
    elif(user_score < computer_score):
        print("Computer is the winner")
    else: # user_score == computer_score
        print("Its a Tie!!!")

# %% [markdown]
# <font size="4.5">**Form 4:** *Function with input parameter/s and return value/s*</font>
#
# ![image.png](attachment:3a8613e8-49f2-46e3-a558-5f3b00285f7b.png)

# %% [markdown]
# # A function that gets user choice and computer choice and returns the result of a single game.

# %%
def determine_winner(user_input, computer_input):
    if (user_input == computer_input):
        #print("Its a draw")
        return "Draw"
    elif((choices[user_input] == "Rock" and choices[computer_input] == "Scissors") or (choices[user_input] == "Paper" and choices[computer_input] == "Rock") or (choices[user_input] == "Scissors" and choices[computer_input] == "Paper")): # logic the condition for user win
        #print("User wins")
        #user_wins += 1
        return "Win"
    else:
        #print("computer wins")
        #comp_wins += 1
        return "Loss"

# %%
import random
def greetings():
    print("Welcome to the RPS game!")

def get_user_inputs():
    while True:
        value = int(input("Press 0 for Rock. Press 1 for Paper. Press 2 for Scissors."))
        if (value <0 or value >2):
            continue
        else:
            return value
            
def get_computer_input():
    return random.randrange(3)
    

def final_result(user_score, computer_score): # user_score, computer_score are called PARAMETERS
    print("The final scores are:")
    print("User:", user_score, "Computer:", computer_score)
    if(user_score > computer_score):
        print("User is the winner")
    elif(user_score < computer_score):
        print("Computer is the winner")
    else: # user_score == computer_score
        print("Its a Tie!!!")

def determine_winner(user_input, computer_input):
    if (user_input == computer_input):
        print("Its a draw")
        return "Draw"
    elif((user_input == "Rock" and computer_input == "Scissors") or (user_input == "Paper" and computer_input == "Rock") or (user_input == "Scissors" and computer_input == "Paper")): # logic the condition for user win
        print("User wins this round")
        #user_wins += 1
        return "Win"
    else:
        print("computer wins this round")
        #comp_wins += 1
        return "Loss"


def mode_user_wish_continuous():
    continue_flag = 1
    user_win = 0
    computer_win = 0
    choices = ["Rock", "Paper", "Scissors"]
    while True:
        greetings()
    
        user_value = get_user_inputs() # get user input
        comp_value = get_computer_input() # gets comp input
        user_choice = choices[user_value] # assigns user choice according to input
        comp_choice = choices[comp_value] # assigns computer choice according to input
        
        result = determine_winner(user_choice, comp_choice)
    
        if result == "Win":
            user_win = user_win + 1
        elif result == "Loss":
            computer_win = computer_win + 1
        else:
            pass
            
        continue_flag = int(input("Do you want to continue? (1/0)"))
        if continue_flag == 0:
            break
    
    final_result(user_win, computer_win)

def mode_x_round(rounds = 5): # rounds is a PARAMETER
    repeat = 0
    user_win = 0
    computer_win = 0
    choices = ["Rock", "Paper", "Scissors"]
    while True:
        greetings()
        repeat = repeat + 1
        print("Round", repeat)
        
        
        user_value = get_user_inputs() # get user input
        comp_value = get_computer_input() # gets comp input
        user_choice = choices[user_value] # assigns user choice according to input
        comp_choice = choices[comp_value] # assigns computer choice according to input
        
        result = determine_winner(user_choice, comp_choice) # user_choice, comp_choice are ARGUMENTS
    
        if result == "Win":
            user_win = user_win + 1
        elif result == "Loss":
            computer_win = computer_win + 1
        else:
            pass
            
        rounds = rounds - 1
        if rounds == 0:
            break
    # final_result(2, 3)
    final_result(user_win, computer_win) # When you are calling the function, the PARAMETERS are called as ARGUMENTS 
                                         # ARGUMENTS actual values that you pass to the function

# %%
game_mode = int(input("Select 1 for x round game. Select 2 for Continuous rounds accoding to user"))

if game_mode == 1:
    num_rounds = int(input("Enter number of rounds you wish to play:"))
    mode_x_round(num_rounds)
elif game_mode == 2:
    mode_user_wish_continuous()
else:
    print("Invalid choice")
# Out:
# Select 1 for x round game. Select 2 for Continuous rounds accoding to user 1
# Enter number of rounds you wish to play: 3
# Welcome to the RPS game!
# Round 1
# Press 0 for Rock. Press 1 for Paper. Press 2 for Scissors. 0
# computer wins this round
# Welcome to the RPS game!
# Round 2
# Press 0 for Rock. Press 1 for Paper. Press 2 for Scissors. 0
# Its a draw
# Welcome to the RPS game!
# Round 3
# Press 0 for Rock. Press 1 for Paper. Press 2 for Scissors. 0
# User wins this round
# The final scores are:
# User: 1 Computer: 1
# Its a Tie!!!

# %%
mode_x_round()
# Out:
# Welcome to the RPS game!
# Round 1
# Press 0 for Rock. Press 1 for Paper. Press 2 for Scissors. 1
# Its a draw
# Welcome to the RPS game!
# Round 2
# Press 0 for Rock. Press 1 for Paper. Press 2 for Scissors. 1
# computer wins this round
# Welcome to the RPS game!
# Round 3
# Press 0 for Rock. Press 1 for Paper. Press 2 for Scissors. 1
# User wins this round
# Welcome to the RPS game!
# Round 4
# Press 0 for Rock. Press 1 for Paper. Press 2 for Scissors. 1
# computer wins this round
# Welcome to the RPS game!
# Round 5
# Press 0 for Rock. Press 1 for Paper. Press 2 for Scissors. 1
# computer wins this round
# The final scores are:
# User: 1 Computer: 3
# Computer is the winner

# %%
def area_circle(radius = 1):
    return 3.142 * radius * radius

# %%
area_circle(5)
# Out:
# 78.55

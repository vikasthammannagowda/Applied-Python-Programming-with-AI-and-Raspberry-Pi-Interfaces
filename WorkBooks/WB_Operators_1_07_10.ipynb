# %% [markdown]
# # Python Operators
#
# <font size="4">Operators are special symbols in Python that perform operations on variables and values. They are the backbone of any programming language, enabling you to perform arithmetic calculations, make comparisons, and manipulate data.</font>

# %% [markdown]
# <font size="6">your_text_here</font>

# %% [markdown]
# <font size="5">Types of Operators in Python</font>
#
# 1. <font size="4">Arithmetic Operators</font>
#
# 2. <font size="4">Relational(Comparision) Operators</font>
#
# 3. <font size="4">Logical Operators</font>
#
# 4. <font size="4">Assignment Operators</font>
#
# 5. <font size="4">Special Operators</font>

# %% [markdown]
# <font size="5">Arithmetic Operators</font>
#
# ![arithmetic_operators.png](attachment:72f438bf-152f-4066-ba20-3f1c8678c620.png)

# %%
# *, /, //, % : has same precedence but ececutes from left to right

3 * 4 / 2  # 3 * 2.0
# Out:
# 6.0

# %%
12 % 7 * 7
# Out:
# 35

# %%
12 % 35
# Out:
# 12

# %%
7/3 # True division -> single / symbol
# Out:
# 2.3333333333333335

# %%
# integer division -> //
#/ for true division and second / for truncating the decimal
7//3
# Out:
# 2

# %%
7.0//3 # expect one such question on QUIZ 1
# Out:
# 2.0

# %%
7//3.0
# Out:
# 2.0

# %%
int(7//3.0) # 2
# Out:
# 2

# %%
float(7//3)

# %%
# when you didvide 7 by 3, what is the remainder 1
7%3
# Out:
# 1

# %%
12 % 5
# Out:
# 2

# %%
10 % 2
# Out:
# 0

# %%
11 % 2
# Out:
# 1

# %%
2 ** 3 # 2^3
# Out:
# 8

# %%
1e4
# Out:
# 10000.0

# %%
2.87e5
# Out:
# 287000.0

# %%
1e-2
# Out:
# 0.01

# %% [markdown]
# # Problem 1
#
# <font size="4">Given a digit in unit(ones) place and tens place, display the number. </font>
#
# Example: digit_ones = 3, digits_tens = 7
#
# Output: num_output = 73

# %%
digit_ones = 3 
digits_tens = 7
print(digits_tens, digits_ones)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 digit_ones = 3
#       2 digits_tens = 7
# ----> 3 print(digits_tens, digits_ones)
#
# NameError: name 'digits_ones' is not defined

# %%
digit_ones = 3 
digits_tens = 7
#print(digits_tens, digit_ones)
number = digits_tens * 10 + digit_ones
print(number)
# Out:
# 73

# %% [markdown]
# # Problem 2
#
# <font size="4">Given a digit in unit(ones) place, tens place, and hundreds place, display the number. </font>
#
# Example: digit_ones = 3, digits_tens = 2, digit_hundreds = 1
#
# Output: num_output = 123

# %% [markdown]
# # Problem 3
#
# <font size="4">Given a 2 digit number, display the digits individually. </font>
#
# Example: num_input = 27
#
# Output:

# %%
num_input = 27
units_digit = num_input % 10
tens_digit = num_input // 10
print("The units place is:", units_digit)
print("The tens place is:", tens_digit)
#print("Original number:", num_input)
# Out:
# The units place is: 7
# The tens place is: 2

# %%
num_input = 27
tens_digit = num_input // 10
#print("Original number:", num_input)
# Out:
# Original number: 27

# %%
num_input = 27
num_input = num_input // 10 # unless you assign back to the same varible, the value does not change
print("Original number:", num_input)
# Out:
# Original number: 2

# %%
27 % 10
# Out:
# 7

# %%
27 // 10
# Out:
# 2

# %% [markdown]
# # Problem 4
#
# <font size="4">Given a 3 digit number, display the digits individually. </font>
#
# Example: num_input = 459
#
# Output:

# %%
num_input = 459
print("Units place:", num_input%10)
num_input = num_input // 10 # num_input = 45
print("Tens place:", num_input%10)
num_input = num_input // 10
print("Hunderds place:", num_input%10)
# Out:
# Units place: 9
# Tens place: 5
# Hunderds place: 4

# %%
num_input = 4598
print("Units place:", num_input%10)
num_input = num_input // 10 # num_input = 45
print("Tens place:", num_input%10)
num_input = num_input // 10
print("Hunderds place:", num_input%10)
num_input = num_input // 10
print("Thousands place:", num_input%10)
# Out:
# Units place: 8
# Tens place: 9
# Hunderds place: 5
# Thousands place: 4

# %%
num_input = 45982
print("Units place:", num_input%10)
num_input = num_input // 10 # num_input = 45
print("Tens place:", num_input%10)
num_input = num_input // 10
print("Hunderds place:", num_input%10)
num_input = num_input // 10
print("Thousands place:", num_input%10)
num_input = num_input // 10
print("ten Thousands place:", num_input%10)
# Out:
# Units place: 2
# Tens place: 8
# Hunderds place: 9
# Thousands place: 5
# ten Thousands place: 4

# %%
num_input = 459826
print("Units place:", num_input%10)
num_input = num_input // 10 # num_input = 45
print("Tens place:", num_input%10)
num_input = num_input // 10
print("Hunderds place:", num_input%10)
num_input = num_input // 10
print("Thousands place:", num_input%10)
num_input = num_input // 10
print("ten Thousands place:", num_input%10)
num_input = num_input // 10
print("100 Thousands place:", num_input%10)
# Out:
# Units place: 6
# Tens place: 2
# Hunderds place: 8
# Thousands place: 9
# ten Thousands place: 5
# 100 Thousands place: 4

# %% [markdown]
# <font size="5">Relational(Comparision) Operator</font>
#
# **IMPORTANT**: *The output of a relational operator is always BOOLEAN (True/False)*
#
# ![relational_operators.png](attachment:d95bc36a-26ab-4102-b4d0-cc89bd7e7a78.png)

# %%
10 > 3
# Out:
# True

# %%
10 > 12
# Out:
# False

# %%
10 >= 10
# Out:
# True

# %%
10 != 10
# Out:
# False

# %%
10 == 10
# Out:
# True

# %%
1 == (10 % 3) # 1 == 1
# Out:
# True
